# %%
import brandtpompe as bp
import pandas as pd
import matplotlib.pyplot as plt
import os

df_bp = pd.read_csv('./img_data_128_emb_hilbert_ordinal_distribution.csv')

i = 255

ordinal_probability = df_bp['ordinal_probability'][i].strip('[]').split(' ')
p = [float(x) for x in ordinal_probability]

m = df_bp['embedding_dimension'][i]
tau = df_bp['time_delay'][i]
color = 'skyblue'

#convertir ordinal_probability en lista de floats
labels = [x for x in range(len(p))]

save_path = None

descrip = 'Image_id=1 Embedding=Hilbert  Size=128x128 Class=Aluminium'


bp.ordinal_probability_plot(p, m, tau, descrip=descrip, color=color, save_path=save_path)
