# %%
import basesetup as setup
import pandas as pd

n = 128

df = setup.transform_dataset (image_path = './img/base/', output_path=f'./img/{n}/', size=(n,n), color_mode='grayscale', enumerate=True, square_crop=True, verbose=False)

print(f"Total images transformed: {len(df)}")
print(df.head())

#guardar df en csv
df.to_csv(f'./img_data_{n}.csv', index=False)
# Out:
# Total images transformed: 810
#                            image_file image_id  image_size           class
# 0  ./img/128/aluminium_foil\00001.png    00001  (128, 128)  aluminium_foil
# 1  ./img/128/aluminium_foil\00002.png    00002  (128, 128)  aluminium_foil
# 2  ./img/128/aluminium_foil\00003.png    00003  (128, 128)  aluminium_foil
# 3  ./img/128/aluminium_foil\00004.png    00004  (128, 128)  aluminium_foil
# 4  ./img/128/aluminium_foil\00005.png    00005  (128, 128)  aluminium_foil
